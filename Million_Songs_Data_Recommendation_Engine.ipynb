# %% [markdown]
# ## Dataset Information
#
# Million Songs Dataset contains of two files: triplet_file and metadata_file. The triplet_file contains user_id, song_id and listen time. The metadata_file contains song_id, title, release, year and artist_name. Million Songs Dataset is a mixture of song from various website with the rating that users gave after listening to the song.
#
# There are 3 types of recommendation system: content-based, collaborative and popularity.

# %% [markdown]
# ## Import modules

# %%
import pandas as pd
import numpy as np
import Recommenders as Recommenders

# %% [markdown]
# ## Loading the dataset

# %%
song_df_1 = pd.read_csv('triplets_file.csv')
song_df_1.head()
# Out:
#                                     user_id             song_id  listen_count
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1

# %%
song_df_2 = pd.read_csv('song_data.csv')
song_df_2.head()
# Out:
#               song_id              title  \
# 0  SOQMMHC12AB0180CB8       Silent Night
# 1  SOVFVAK12A8C1350D9        Tanssi vaan
# 2  SOGTUKN12AB017F4F1  No One Could Ever
# 3  SOBNYVR12A8C13558C      Si Vos Querés
# 4  SOHSBXH12A8C13B0DF   Tangle Of Aspens
#
#                                 release       artist_name    year
# 0                 Monster Ballads X-Mas  Faster Pussy cat  2003.0
# 1                           Karkuteillä  Karkkiautomaatti  1995.0
# 2                                Butter    Hudson Mohawke  2006.0
# 3                               De Culo       Yerba Brava  2003.0
# 4  Rene Ablaze Presents Winter Sessions        Der Mystic     0.0

# %%
# combine both data
song_df = pd.merge(song_df_1, song_df_2.drop_duplicates(['song_id']), on='song_id', how='left')
song_df.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1
#
#              title              release    artist_name    year
# 0              NaN                  NaN            NaN     NaN
# 1  Entre Dos Aguas  Flamenco Para Niños  Paco De Lucia  1976.0
# 2              NaN                  NaN            NaN     NaN
# 3              NaN                  NaN            NaN     NaN
# 4              NaN                  NaN            NaN     NaN

# %%
print(len(song_df_1), len(song_df_2))
# Out:
# 33258 40146

# %%
len(song_df)
# Out:
# 33258

# %% [markdown]
# ## Data Preprocessing

# %%
# creating new feature combining title and artist name
song_df['song'] = song_df['title']+' - '+song_df['artist_name']
song_df.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1
#
#              title              release    artist_name    year  \
# 0              NaN                  NaN            NaN     NaN
# 1  Entre Dos Aguas  Flamenco Para Niños  Paco De Lucia  1976.0
# 2              NaN                  NaN            NaN     NaN
# 3              NaN                  NaN            NaN     NaN
# 4              NaN                  NaN            NaN     NaN
#
#                               song
# 0                              NaN
# 1  Entre Dos Aguas - Paco De Lucia
# 2                              NaN
# 3                              NaN
# 4                              NaN

# %%
# taking top 10k samples for quick results
song_df = song_df.head(10000)

# %%
# cummulative sum of listen count of the songs
song_grouped = song_df.groupby(['song']).agg({'listen_count':'count'}).reset_index()
song_grouped.head()
# Out:
#                                       song  listen_count
# 0  (Anaesthesia) Pulling Teath - Metallica             1
# 1                       A Dream - Cut Copy             4
# 2             A Kind Of Hope - Pilot Speed             1
# 3      Achy Breaky Heart - Billy Ray Cyrus             1
# 4                 Addicted - Amy Winehouse             2

# %%
grouped_sum = song_grouped['listen_count'].sum()
song_grouped['percentage'] = (song_grouped['listen_count'] / grouped_sum ) * 100
song_grouped.sort_values(['listen_count', 'song'], ascending=[0,1])
# Out:
#                                                   song  listen_count  \
# 129  Nothin' On You [feat. Bruno Mars] (Album Versi...            16
# 227       You've Got The Love - Florence + The Machine            10
# 86                    If I Ain't Got You - Alicia Keys             9
# 198                             Toxic - Britney Spears             9
# 145  Rabbit Heart (Raise It Up) - Florence + The Ma...             8
# ..                                                 ...           ...
# 222            You Love Me (Album Version) - Devotchka             1
# 224                 You Wanted A Hit - LCD Soundsystem             1
# 225         You Were Meant For Me (LP Version) - Jewel             1
# 226  You'll Never Know (My Love) (Bovellian 07 Mix)...             1
# 228       Your Visits Are Getting Shorter - Bloc Party             1
#
#      percentage
# 129    3.579418
# 227    2.237136
# 86     2.013423
# 198    2.013423
# 145    1.789709
# ..          ...
# 222    0.223714
# 224    0.223714
# 225    0.223714
# 226    0.223714
# 228    0.223714
#
# [231 rows x 3 columns]

# %% [markdown]
# ## Popularity Recommendation Engine

# %%
pr = Recommenders.popularity_recommender_py()

# %%
pr.create(song_df, 'user_id', 'song')

# %%
# display the top 10 popular songs
pr.recommend(song_df['user_id'][5])
# Out:
#                                       user_id  \
# 129  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 227  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 86   b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 198  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 145  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 75   b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 55   b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 28   b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 62   b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 81   b80344d063b5ccb3212f76538f3d9e43d87dca9e
#
#                                                   song  score  Rank
# 129  Nothin' On You [feat. Bruno Mars] (Album Versi...     16   1.0
# 227       You've Got The Love - Florence + The Machine     10   2.0
# 86                    If I Ain't Got You - Alicia Keys      9   3.0
# 198                             Toxic - Britney Spears      9   4.0
# 145  Rabbit Heart (Raise It Up) - Florence + The Ma...      8   5.0
# 75                     Here Without You - 3 Doors Down      7   6.0
# 55      Eenie Meenie - Sean Kingston and Justin Bieber      6   7.0
# 28                               Big Me - Foo Fighters      5   8.0
# 62                            Forgive Me - Leona Lewis      5   9.0
# 81                          I Can't Stay - The Killers      5  10.0

# %%
pr.recommend(song_df['user_id'][100])
# Out:
#                                       user_id  \
# 129  e006b1a48f466bf59feefed32bec6494495a4436
# 227  e006b1a48f466bf59feefed32bec6494495a4436
# 86   e006b1a48f466bf59feefed32bec6494495a4436
# 198  e006b1a48f466bf59feefed32bec6494495a4436
# 145  e006b1a48f466bf59feefed32bec6494495a4436
# 75   e006b1a48f466bf59feefed32bec6494495a4436
# 55   e006b1a48f466bf59feefed32bec6494495a4436
# 28   e006b1a48f466bf59feefed32bec6494495a4436
# 62   e006b1a48f466bf59feefed32bec6494495a4436
# 81   e006b1a48f466bf59feefed32bec6494495a4436
#
#                                                   song  score  Rank
# 129  Nothin' On You [feat. Bruno Mars] (Album Versi...     16   1.0
# 227       You've Got The Love - Florence + The Machine     10   2.0
# 86                    If I Ain't Got You - Alicia Keys      9   3.0
# 198                             Toxic - Britney Spears      9   4.0
# 145  Rabbit Heart (Raise It Up) - Florence + The Ma...      8   5.0
# 75                     Here Without You - 3 Doors Down      7   6.0
# 55      Eenie Meenie - Sean Kingston and Justin Bieber      6   7.0
# 28                               Big Me - Foo Fighters      5   8.0
# 62                            Forgive Me - Leona Lewis      5   9.0
# 81                          I Can't Stay - The Killers      5  10.0

# %% [markdown]
# ## Item Similarity Recommendation

# %%
ir = Recommenders.item_similarity_recommender_py()
ir.create(song_df, 'user_id', 'song')

# %%
user_items = ir.get_user_items(song_df['user_id'][5])

# %%
# display user songs history
for user_item in user_items:
    print(user_item)
# Out:
# nan
# Entre Dos Aguas - Paco De Lucia
# Love Song For No One - John Mayer

# %%
# give song recommendation for that user
ir.recommend(song_df['user_id'][5])
# Out:
# No. of unique songs for the user: 3
# no. of unique songs in the training set: 232
# Non zero values in cooccurence_matrix :8
#                                     user_id  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 5  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 6  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 7  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 8  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 9  b80344d063b5ccb3212f76538f3d9e43d87dca9e
#
#                                                 song     score  rank
# 0       DONTTRUSTME (Explicit Album Version) - 3OH!3  0.111111     1
# 1                    Here Without You - 3 Doors Down  0.041667     2
# 2  Rabbit Heart (Raise It Up) - Florence + The Ma...  0.037037     3
# 3                             Toxic - Britney Spears  0.033333     4
# 4  Clenching The Fists Of Dissent (Explicit Album...  0.000000     5
# 5          Helpless - Crosby_ Stills_ Nash and Young  0.000000     6
# 6                 We've Only Just Begun - Carpenters  0.000000     7
# 7                 You Wanted A Hit - LCD Soundsystem  0.000000     8
# 8                                 The Light - Common  0.000000     9
# 9  Wooden Ships (LP Version) - Crosby_ Stills & Nash  0.000000    10

# %%
# give related songs based on the words
ir.get_similar_items(['Oliver James - Fleet Foxes', 'The End - Pearl Jam'])
# Out:
# no. of unique songs in the training set: 232
# Non zero values in cooccurence_matrix :0
#   user_id                                               song  score  rank
# 0          Clenching The Fists Of Dissent (Explicit Album...    0.0     1
# 1                  Helpless - Crosby_ Stills_ Nash and Young    0.0     2
# 2                         We've Only Just Begun - Carpenters    0.0     3
# 3                         You Wanted A Hit - LCD Soundsystem    0.0     4
# 4                                         The Light - Common    0.0     5
# 5          Wooden Ships (LP Version) - Crosby_ Stills & Nash    0.0     6
# 6          Arc Of Time (time Code) (Album Version) - Brig...    0.0     7
# 7                              Slow Death - Flamin' Groovies    0.0     8
# 8                              Lo Que Yo No Tengo - Son By 4    0.0     9
# 9                                    Wonderwall - Ryan Adams    0.0    10
